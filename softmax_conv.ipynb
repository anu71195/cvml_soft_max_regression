# %%
from __future__ import division, print_function, absolute_import
import matplotlib.pyplot as plt
# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=False)

import tensorflow as tf

def myPlot(X,Y):
    plt.plot(X,Y);
    plt.xlabel("Channels");
    plt.ylabel("accuracy")
    plt.show();
    

# Training Parameters
learning_rate = 0.001
num_steps = 2000
batch_size = 128

# Network Parameters
num_input = 784 # MNIST data input (img shape: 28*28)
num_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.25 # Dropout, probability to drop a unit
# Out:
# WARNING:tensorflow:From <ipython-input-1-825ecc8bf76d>:5: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/udayraj/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/udayraj/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/udayraj/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/udayraj/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
# Create the neural network
def conv_net(x_dict, n_classes, dropout,k_size, reuse, is_training):
    # Define a scope for reusing the variables
    with tf.variable_scope('ConvNet', reuse=reuse):
        # TF Estimator input is a dict, in case of multiple inputs
        x = x_dict['images']

        # MNIST data input is a 1-D vector of 784 features (28*28 pixels)
        # Reshape to match picture format [Height x Width x Channel]
        # Tensor input become 4-D: [Batch Size, Height, Width, Channel]
        x = tf.reshape(x, shape=[-1, 28, 28, 1])

        # Convolution Layer with 32 filters and a kernel size of 5
        conv1 = tf.layers.conv2d(x, k_size, 5, activation=tf.nn.relu)
        # Max Pooling (down-sampling) with strides of 2 and kernel size of 2
        conv1 = tf.layers.max_pooling2d(conv1, 2, 2)

        # Convolution Layer with 64 filters and a kernel size of 3
        conv2 = tf.layers.conv2d(conv1, 64, 3, activation=tf.nn.relu)
        # Max Pooling (down-sampling) with strides of 2 and kernel size of 2
        conv2 = tf.layers.max_pooling2d(conv2, 2, 2)

        # Flatten the data to a 1-D vector for the fully connected layer
        fc1 = tf.contrib.layers.flatten(conv1)

        # Fully connected layer (in tf contrib folder for now)
        fc1 = tf.layers.dense(fc1, 1024)
        # Apply Dropout (if is_training is False, dropout is not applied)
        fc1 = tf.layers.dropout(fc1, rate=dropout, training=is_training)

        # Output layer, class prediction
        out = tf.layers.dense(fc1, n_classes)

    return out

# %%
# Define the model function (following TF Estimator Template)
def model_fn(features, labels, mode, params):
    k_size = params["k_size"]
    # Build the neural network
    # Because Dropout have different behavior at training and prediction time, we
    # need to create 2 distinct computation graphs that still share the same weights.
    logits_train = conv_net(features, num_classes, dropout,k_size, reuse=False,
                            is_training=True)
    logits_test = conv_net(features, num_classes, dropout,k_size, reuse=True,
                           is_training=False)

    # Predictions
    pred_classes = tf.argmax(logits_test, axis=1)
    pred_probas = tf.nn.softmax(logits_test)

    # If prediction mode, early return
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=pred_classes)

        # Define loss and optimizer
    loss_op = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
        logits=logits_train, labels=tf.cast(labels, dtype=tf.int32)))
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    train_op = optimizer.minimize(loss_op,
                                  global_step=tf.train.get_global_step())

    # Evaluate the accuracy of the model
    acc_op = tf.metrics.accuracy(labels=labels, predictions=pred_classes)

    # TF Estimators requires to return a EstimatorSpec, that specify
    # the different ops for training, evaluating, ...
    estim_specs = tf.estimator.EstimatorSpec(
        mode=mode,
        predictions=pred_classes,
        loss=loss_op,
        train_op=train_op,
        eval_metric_ops={'accuracy': acc_op})

    return estim_specs

# %%
# Build the Estimator
X_Ksize=[16, 24, 32, 40, 48, 56]
#X_Ksize = [32]
Y_Ksaccuracy=[];

for X_i in X_Ksize:
    model = tf.estimator.Estimator(model_fn, params = {"k_size" : X_i})
    # Define the input function for training
    input_fn = tf.estimator.inputs.numpy_input_fn(
        x={'images': mnist.train.images}, y=mnist.train.labels,
        batch_size=batch_size,num_epochs=None, shuffle=True)
    # Train the Model
    model.train(input_fn, steps=num_steps)

    # Evaluate the Model
    # Define the input function for evaluating
    input_fn = tf.estimator.inputs.numpy_input_fn(
        x={'images': mnist.test.images}, y=mnist.test.labels,
        batch_size=batch_size,shuffle=False)
    # Use the Estimator 'evaluate' method
    e = model.evaluate(input_fn)
    Y_Ksaccuracy.append(e['accuracy']);
    print("Testing Accuracy:", e['accuracy'])
myPlot(X_Ksize,Y_Ksaccuracy)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpo9egh53f
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpo9egh53f', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f92de6557f0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpo9egh53f/model.ckpt.
# INFO:tensorflow:loss = 2.3367045, step = 1
# INFO:tensorflow:global_step/sec: 12.7626
# INFO:tensorflow:loss = 0.11407027, step = 101 (7.836 sec)
# INFO:tensorflow:global_step/sec: 13.3725
# INFO:tensorflow:loss = 0.09044474, step = 201 (7.478 sec)
# INFO:tensorflow:global_step/sec: 13.9384
# INFO:tensorflow:loss = 0.23830262, step = 301 (7.175 sec)
# INFO:tensorflow:global_step/sec: 12.0149
# INFO:tensorflow:loss = 0.15907288, step = 401 (8.323 sec)
# INFO:tensorflow:global_step/sec: 12.2029
# INFO:tensorflow:loss = 0.026524689, step = 501 (8.194 sec)
# INFO:tensorflow:global_step/sec: 12.3154
# INFO:tensorflow:loss = 0.0793591, step = 601 (8.121 sec)
# INFO:tensorflow:global_step/sec: 13.7202
# INFO:tensorflow:loss = 0.04043076, step = 701 (7.288 sec)
# INFO:tensorflow:global_step/sec: 12.3266
# INFO:tensorflow:loss = 0.047365963, step = 801 (8.112 sec)
# INFO:tensorflow:global_step/sec: 12.4779
# INFO:tensorflow:loss = 0.016316533, step = 901 (8.014 sec)
# INFO:tensorflow:global_step/sec: 13.8703
# INFO:tensorflow:loss = 0.041652516, step = 1001 (7.210 sec)
# INFO:tensorflow:global_step/sec: 13.5701
# INFO:tensorflow:loss = 0.11388328, step = 1101 (7.369 sec)
# INFO:tensorflow:global_step/sec: 13.8815
# INFO:tensorflow:loss = 0.012908521, step = 1201 (7.204 sec)
# INFO:tensorflow:global_step/sec: 13.7958
# INFO:tensorflow:loss = 0.051430516, step = 1301 (7.248 sec)
# INFO:tensorflow:global_step/sec: 13.8934
# INFO:tensorflow:loss = 0.05352331, step = 1401 (7.198 sec)
# INFO:tensorflow:global_step/sec: 13.4186
# INFO:tensorflow:loss = 0.06718557, step = 1501 (7.452 sec)
# INFO:tensorflow:global_step/sec: 13.8561
# INFO:tensorflow:loss = 0.07889298, step = 1601 (7.217 sec)
# INFO:tensorflow:global_step/sec: 13.8229
# INFO:tensorflow:loss = 0.020751718, step = 1701 (7.234 sec)
# INFO:tensorflow:global_step/sec: 13.1601
# INFO:tensorflow:loss = 0.054918654, step = 1801 (7.599 sec)
# INFO:tensorflow:global_step/sec: 13.1128
# INFO:tensorflow:loss = 0.03998179, step = 1901 (7.626 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into /tmp/tmpo9egh53f/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0050081243.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-02-07:50:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpo9egh53f/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-02-07:50:32
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.9859, global_step = 2000, loss = 0.04808268
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: /tmp/tmpo9egh53f/model.ckpt-2000
# Testing Accuracy: 0.9859
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpm8pzrlee
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpm8pzrlee', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f92d22c5f98>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpm8pzrlee/model.ckpt.
# INFO:tensorflow:loss = 2.3207016, step = 1
# INFO:tensorflow:global_step/sec: 8.24721
# INFO:tensorflow:loss = 0.14496374, step = 101 (12.126 sec)
# INFO:tensorflow:global_step/sec: 9.21821
# INFO:tensorflow:loss = 0.25556764, step = 201 (10.848 sec)
# INFO:tensorflow:global_step/sec: 9.76043
# INFO:tensorflow:loss = 0.0668363, step = 301 (10.247 sec)
# INFO:tensorflow:global_step/sec: 10.2046
# INFO:tensorflow:loss = 0.051217128, step = 401 (9.798 sec)
# INFO:tensorflow:global_step/sec: 9.66066
# INFO:tensorflow:loss = 0.08585063, step = 501 (10.351 sec)
# INFO:tensorflow:global_step/sec: 9.68432
# INFO:tensorflow:loss = 0.02070404, step = 601 (10.326 sec)
# INFO:tensorflow:global_step/sec: 6.53804
# INFO:tensorflow:loss = 0.046046115, step = 701 (15.297 sec)
# INFO:tensorflow:global_step/sec: 6.47724
# INFO:tensorflow:loss = 0.024089066, step = 801 (15.437 sec)
# INFO:tensorflow:global_step/sec: 8.28843
# INFO:tensorflow:loss = 0.03477564, step = 901 (12.065 sec)
# INFO:tensorflow:global_step/sec: 9.64189
# INFO:tensorflow:loss = 0.11330131, step = 1001 (10.371 sec)
# INFO:tensorflow:global_step/sec: 9.55609
# INFO:tensorflow:loss = 0.014011823, step = 1101 (10.464 sec)
# INFO:tensorflow:global_step/sec: 9.28832
# INFO:tensorflow:loss = 0.015732912, step = 1201 (10.767 sec)
# INFO:tensorflow:global_step/sec: 9.10296
# INFO:tensorflow:loss = 0.036279485, step = 1301 (10.986 sec)
# INFO:tensorflow:global_step/sec: 8.96551
# INFO:tensorflow:loss = 0.011686098, step = 1401 (11.153 sec)
# INFO:tensorflow:global_step/sec: 9.05469
# INFO:tensorflow:loss = 0.03586254, step = 1501 (11.044 sec)
# INFO:tensorflow:global_step/sec: 8.98427
# INFO:tensorflow:loss = 0.0056579835, step = 1601 (11.130 sec)
# INFO:tensorflow:global_step/sec: 9.55648
# INFO:tensorflow:loss = 0.02629678, step = 1701 (10.464 sec)
# INFO:tensorflow:global_step/sec: 9.24857
# INFO:tensorflow:loss = 0.023793131, step = 1801 (10.813 sec)
# INFO:tensorflow:global_step/sec: 9.10861
# INFO:tensorflow:loss = 0.03089824, step = 1901 (10.977 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into /tmp/tmpm8pzrlee/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.017734658.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-02-07:54:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpm8pzrlee/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-02-07:54:24
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.9849, global_step = 2000, loss = 0.050685875
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: /tmp/tmpm8pzrlee/model.ckpt-2000
# Testing Accuracy: 0.9849
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpyy8stdid
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpyy8stdid', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f92d9b96c88>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpyy8stdid/model.ckpt.
# INFO:tensorflow:loss = 2.2793403, step = 1
# INFO:tensorflow:global_step/sec: 7.08467
# INFO:tensorflow:loss = 0.10210102, step = 101 (14.116 sec)
# INFO:tensorflow:global_step/sec: 6.34379
# INFO:tensorflow:loss = 0.09426554, step = 201 (15.764 sec)
# INFO:tensorflow:global_step/sec: 6.7675
# INFO:tensorflow:loss = 0.035785105, step = 301 (14.776 sec)
# INFO:tensorflow:global_step/sec: 7.39394
# INFO:tensorflow:loss = 0.042582482, step = 401 (13.527 sec)
# INFO:tensorflow:global_step/sec: 6.68333
# INFO:tensorflow:loss = 0.063208, step = 501 (14.960 sec)
# INFO:tensorflow:global_step/sec: 7.03722
# INFO:tensorflow:loss = 0.028577887, step = 601 (14.210 sec)
# INFO:tensorflow:global_step/sec: 6.42565
# INFO:tensorflow:loss = 0.15866493, step = 701 (15.563 sec)
# INFO:tensorflow:global_step/sec: 6.88231
# INFO:tensorflow:loss = 0.031961806, step = 801 (14.529 sec)
# INFO:tensorflow:global_step/sec: 6.57499
# INFO:tensorflow:loss = 0.09981716, step = 901 (15.214 sec)
# INFO:tensorflow:global_step/sec: 6.17067
# INFO:tensorflow:loss = 0.0076998966, step = 1001 (16.203 sec)
# INFO:tensorflow:global_step/sec: 6.25238
# INFO:tensorflow:loss = 0.014615808, step = 1101 (15.997 sec)
# INFO:tensorflow:global_step/sec: 6.76346
# INFO:tensorflow:loss = 0.026069295, step = 1201 (14.782 sec)
# INFO:tensorflow:global_step/sec: 6.34396
# INFO:tensorflow:loss = 0.004150234, step = 1301 (15.766 sec)
# INFO:tensorflow:global_step/sec: 6.71192
# INFO:tensorflow:loss = 0.05181374, step = 1401 (14.896 sec)
# INFO:tensorflow:global_step/sec: 6.79118
# INFO:tensorflow:loss = 0.039138895, step = 1501 (14.725 sec)
# INFO:tensorflow:global_step/sec: 6.54232
# INFO:tensorflow:loss = 0.008563637, step = 1601 (15.285 sec)
# INFO:tensorflow:global_step/sec: 6.19904
# INFO:tensorflow:loss = 0.046058998, step = 1701 (16.131 sec)
# INFO:tensorflow:global_step/sec: 7.19097
# INFO:tensorflow:loss = 0.014143216, step = 1801 (13.906 sec)
# INFO:tensorflow:global_step/sec: 6.90805
# INFO:tensorflow:loss = 0.008713857, step = 1901 (14.476 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into /tmp/tmpyy8stdid/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.010394405.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-02-07:59:25
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpyy8stdid/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-02-07:59:29
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.9856, global_step = 2000, loss = 0.046887647
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: /tmp/tmpyy8stdid/model.ckpt-2000
# Testing Accuracy: 0.9856
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmppl2e0sfk
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmppl2e0sfk', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f92ddc8ce80>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmppl2e0sfk/model.ckpt.
# INFO:tensorflow:loss = 2.3189988, step = 1
# INFO:tensorflow:global_step/sec: 5.07315
# INFO:tensorflow:loss = 0.073399685, step = 101 (19.713 sec)
# INFO:tensorflow:global_step/sec: 3.94469
# INFO:tensorflow:loss = 0.15758044, step = 201 (25.360 sec)
# INFO:tensorflow:global_step/sec: 3.85393
# INFO:tensorflow:loss = 0.10422495, step = 301 (25.940 sec)
# INFO:tensorflow:global_step/sec: 4.04472
# INFO:tensorflow:loss = 0.060507357, step = 401 (24.735 sec)
# INFO:tensorflow:global_step/sec: 4.27985
# INFO:tensorflow:loss = 0.02978379, step = 501 (23.352 sec)
# INFO:tensorflow:global_step/sec: 4.92391
# INFO:tensorflow:loss = 0.11901177, step = 601 (20.309 sec)
# INFO:tensorflow:global_step/sec: 5.42442
# INFO:tensorflow:loss = 0.06309203, step = 701 (18.437 sec)
# INFO:tensorflow:global_step/sec: 5.8023
# INFO:tensorflow:loss = 0.12340611, step = 801 (17.232 sec)
# INFO:tensorflow:global_step/sec: 6.12256
# INFO:tensorflow:loss = 0.07988076, step = 901 (16.334 sec)
# INFO:tensorflow:global_step/sec: 6.1548
# INFO:tensorflow:loss = 0.0462825, step = 1001 (16.247 sec)
# INFO:tensorflow:global_step/sec: 6.2134
# INFO:tensorflow:loss = 0.014692282, step = 1101 (16.094 sec)
# INFO:tensorflow:global_step/sec: 5.10111
# INFO:tensorflow:loss = 0.11013368, step = 1201 (19.603 sec)
# INFO:tensorflow:global_step/sec: 4.79065
# INFO:tensorflow:loss = 0.027775576, step = 1301 (20.875 sec)
# INFO:tensorflow:global_step/sec: 5.67079
# INFO:tensorflow:loss = 0.02825914, step = 1401 (17.637 sec)
# INFO:tensorflow:global_step/sec: 5.5234
# INFO:tensorflow:loss = 0.02643898, step = 1501 (18.110 sec)
# INFO:tensorflow:global_step/sec: 5.27102
# INFO:tensorflow:loss = 0.084604174, step = 1601 (18.964 sec)
# INFO:tensorflow:global_step/sec: 5.16674
# INFO:tensorflow:loss = 0.025265122, step = 1701 (19.360 sec)
# INFO:tensorflow:global_step/sec: 4.88489
# INFO:tensorflow:loss = 0.040585164, step = 1801 (20.466 sec)
